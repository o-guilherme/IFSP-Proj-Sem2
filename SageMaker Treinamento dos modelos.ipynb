# %% [markdown]
# # Treinamento e comparação dos modelos
#
# Objetivo: Treinar vários modelos com vários datasets para comparar os resultados.

# %% [raw]
# #Setting S3FileSystem version
# !pip install s3fs==2022.01.0

# %% [raw]
# %pip install phik
# %pip install imblearn
# %pip install yellowbrick

# %%
#Importing most used modules
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import phik
sns.set_palette('viridis')
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, mean_absolute_error, mean_squared_error, r2_score, ConfusionMatrixDisplay
from yellowbrick.classifier import ConfusionMatrix
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier, ExtraTreesClassifier
from sklearn.metrics import roc_curve
import joblib
import warnings
warnings.filterwarnings("ignore") #Filtering some warnings for better presentation

# %% [markdown]
# ### 1. Carregando os datasets

# %%
#Loading the datasets - local
test_sets = ['numeric','categoricals_binned','one_hot_encoded','outliers_removed',
             'one_hot_encoded_rescaled','oversampled+','oversampled-','smoted+','smoted-']
datasets = {}
for key in test_sets:
    datasets[key] = pd.read_csv(f'datasets/{key}.csv')

# %% [raw]
# #Loading the datasets
# test_sets = ['numeric','categoricals_binned','one_hot_encoded','outliers_removed',
#              'one_hot_encoded_rescaled','oversampled+','oversampled-','smoted+','smoted-']
# datasets = {}
# for key in test_sets:
#     datasets[key] = pd.read_csv(f's3://trabalho-ifsp-campinas-interdisciplinar-2022-2/{key}.csv')

# %%
#Defining the X,y spliter
def df_splitter(dataset, target = 'Response'):
    X = dataset.drop(columns=[target])
    y = dataset[target].values
    return X, y

# %%
# Defining the printing function
def display_scores(scores):
    print("Scores:", scores)
    print("\nMean:", scores.mean())
    print("Standard deviation:", scores.std())

# %% [markdown]
# ### 2. Testando os datasets
#
# Como temos várias opções de datasets, nós vamos fazer um teste rápido dos modelos para ter uma noção dos resultados, para selecionar futuros modelos.

# %%
first_results = []

# %% [markdown]
# #### 2.1 Classificador K-Neighbors (KNN)

# %%
knn_clf = KNeighborsClassifier(n_neighbors=5, n_jobs = -1)
for key in test_sets:
    X, y = df_splitter(datasets[key])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)
    knn_test = cross_val_score(knn_clf,X_train,y_train, n_jobs=-1, cv=3, scoring='accuracy')
    first_results.append({'model':'KNN', 'dataset':key, 'score':knn_test.mean()})
    print(f'\n-----\nDataset: {key}')
    display_scores(knn_test)
# Out:
# -----
# Dataset: numeric
# Scores: [0.71228536 0.71211675 0.71491745]
#
# Mean: 0.7131065181467098
# Standard deviation: 0.0012823729935557734
#
# -----
# Dataset: categoricals_binned
# Scores: [0.71059032 0.70769458 0.71005307]
#
# Mean: 0.7094459858904245
# Standard deviation: 0.0012577064482832434
#
# -----
# Dataset: one_hot_encoded
# Scores: [0.71022183 0.70850531 0.70953715]
#
# Mean: 0.7094214273332063
# Standard deviation: 0.0007055284432189075
#
# -----
# Dataset: outliers_removed
# Scores: [0.71475655 0.70724399 0.71301221]
#
# Mean: 0.711670917757777
# Standard deviation: 0.00321029198290776
#
# -----
# Dataset: one_hot_encoded_rescaled
# Scores: [0.71464367 0.71395932 0.71587559]
#
# Mean: 0.7148261929129059
# Standard deviation: 0.0007928897487709854
#
# -----
# Dataset: oversampled+
# Scores: [0.62038204 0.6198303  0.6208    ]
#
# Mean: 0.620337448371037
# Standard deviation: 0.0003971309629555497
#
# -----
# Dataset: oversampled-
# Scores: [0.61266322 0.611905   0.6137282 ]
#
# Mean: 0.6127654698725807
# Standard deviation: 0.0007478214047553315
#
# -----
# Dataset: smoted+
# Scores: [0.62004266 0.61682424 0.61197576]
#
# Mean: 0.6162808881993601
# Standard deviation: 0.0033156369510721063
#
# -----
# Dataset: smoted-
# Scores: [0.64818921 0.64856608 0.65635163]
#
# Mean: 0.6510356396109004
# Standard deviation: 0.003762120960200458

# %% [markdown]
# #### 2.2 Classificador Bayesiano Ingênuo Gaussiano (Gaussian Naive Bayes)

# %%
nbg_clf = GaussianNB()
for key in test_sets:
    X, y = df_splitter(datasets[key])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)
    nbg_test = cross_val_score(nbg_clf,X_train,y_train, n_jobs=-1, cv=5, scoring='accuracy')
    first_results.append({'model':'Naive Bayes', 'dataset':key, 'score':nbg_test.mean()})
    print(f'\n-----\nDataset: {key}')
    display_scores(nbg_test)
# Out:
# -----
# Dataset: numeric
# Scores: [0.75592679 0.74695983 0.74462597 0.75113622 0.74695983]
#
# Mean: 0.7491217295172583
# Standard deviation: 0.003998162378626328
#
# -----
# Dataset: categoricals_binned
# Scores: [0.75690947 0.74953937 0.74376612 0.75224174 0.746837  ]
#
# Mean: 0.749858739712566
# Standard deviation: 0.004510973372125921
#
# -----
# Dataset: one_hot_encoded
# Scores: [0.75506695 0.74941653 0.7443803  0.7492937  0.74867952]
#
# Mean: 0.7493673995823609
# Standard deviation: 0.003401088891060924
#
# -----
# Dataset: outliers_removed
# Scores: [0.75418227 0.75156055 0.74956305 0.75402672 0.7445374 ]
#
# Mean: 0.7507739966071254
# Standard deviation: 0.003554625483263591
#
# -----
# Dataset: one_hot_encoded_rescaled
# Scores: [0.72583221 0.72976293 0.72816607 0.71919912 0.72288417]
#
# Mean: 0.725168898169758
# Standard deviation: 0.003778530191324014
#
# -----
# Dataset: oversampled+
# Scores: [0.52828054 0.53139394 0.53373737 0.52711111 0.52864646]
#
# Mean: 0.5298338863750629
# Standard deviation: 0.0024044679324950508
#
# -----
# Dataset: oversampled-
# Scores: [0.54151269 0.53420383 0.52878377 0.53268725 0.5342477 ]
#
# Mean: 0.5342870482870001
# Standard deviation: 0.0041246509318381575
#
# -----
# Dataset: smoted+
# Scores: [0.73796057 0.73519192 0.73567677 0.73591919 0.73139394]
#
# Mean: 0.735228477404948
# Standard deviation: 0.0021376338598672697
#
# -----
# Dataset: smoted-
# Scores: [0.6317648  0.63775971 0.63299663 0.63428055 0.6364159 ]
#
# Mean: 0.6346435196920759
# Standard deviation: 0.002190112981087577

# %% [markdown]
# #### 2.3 Classificador Máquina Vetores de Suporte (Support Vector Machine)

# %%
svm = SVC(random_state = 1216, C = 1.0, cache_size = 1024)
for key in test_sets:
    X, y = df_splitter(datasets[key])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)
    svc_test = cross_val_score(svm,X_train,y_train, n_jobs=-1, cv=2, scoring='accuracy')
    first_results.append({'model':'Support Vector Machine', 'dataset':key, 'score':svc_test.mean()})
    print(f'\n-----\nDataset: {key}')
    display_scores(svc_test)
# Out:
# -----
# Dataset: numeric
# Scores: [0.76037931 0.76036753]
#
# Mean: 0.7603734183543323
# Standard deviation: 5.88690779129708e-06
#
# -----
# Dataset: categoricals_binned
# Scores: [0.76037931 0.76036753]
#
# Mean: 0.7603734183543323
# Standard deviation: 5.88690779129708e-06
#
# -----
# Dataset: one_hot_encoded
# Scores: [0.76037931 0.76036753]
#
# Mean: 0.7603734183543323
# Standard deviation: 5.88690779129708e-06
#
# -----
# Dataset: outliers_removed
# Scores: [0.76038753 0.76038753]
#
# Mean: 0.7603875349580503
# Standard deviation: 0.0
#
# -----
# Dataset: one_hot_encoded_rescaled
# Scores: [0.76037931 0.76036753]
#
# Mean: 0.7603734183543323
# Standard deviation: 5.88690779129708e-06
#
# -----
# Dataset: oversampled+
# Scores: [0.5166462  0.53096516]
#
# Mean: 0.5238056758678648
# Standard deviation: 0.007159480250824246
#
# -----
# Dataset: oversampled-
# Scores: [0.50775245 0.50517394]
#
# Mean: 0.5064631951570698
# Standard deviation: 0.0012892521197188644
#
# -----
# Dataset: smoted+
# Scores: [0.67318508 0.66920939]
#
# Mean: 0.6711972331760294
# Standard deviation: 0.001987846661064052
#
# -----
# Dataset: smoted-
# Scores: [0.50463176 0.50550245]
#
# Mean: 0.5050671030557676
# Standard deviation: 0.00043534430141511926

# %% [markdown]
# #### 2.4 Árvores de decisão

# %%
dtc = DecisionTreeClassifier(random_state=1216)
for key in test_sets:
    X, y = df_splitter(datasets[key])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)
    dtc_test = cross_val_score(dtc,X_train,y_train, n_jobs=-1, cv=2, scoring='accuracy')
    first_results.append({'model':'Decision Tree', 'dataset':key, 'score':dtc_test.mean()})
    print(f'\n-----\nDataset: {key}')
    display_scores(dtc_test)
# Out:
# -----
# Dataset: numeric
# Scores: [0.66545472 0.66273585]
#
# Mean: 0.664095286587949
# Standard deviation: 0.00135943753134532
#
# -----
# Dataset: categoricals_binned
# Scores: [0.63725249 0.64042846]
#
# Mean: 0.6388404763047
# Standard deviation: 0.001587982814796829
#
# -----
# Dataset: one_hot_encoded
# Scores: [0.64398369 0.640625  ]
#
# Mean: 0.6423043439542082
# Standard deviation: 0.0016793439542082123
#
# -----
# Dataset: outliers_removed
# Scores: [0.64627447 0.64372753]
#
# Mean: 0.6450009988014382
# Standard deviation: 0.0012734718337994444
#
# -----
# Dataset: one_hot_encoded_rescaled
# Scores: [0.64378716 0.640625  ]
#
# Mean: 0.6422060783422592
# Standard deviation: 0.0015810783422591235
#
# -----
# Dataset: oversampled+
# Scores: [0.72916801 0.73243261]
#
# Mean: 0.7308003102980154
# Standard deviation: 0.0016322968517680225
#
# -----
# Dataset: oversampled-
# Scores: [0.73010972 0.73479846]
#
# Mean: 0.7324540897191807
# Standard deviation: 0.0023443728806024633
#
# -----
# Dataset: smoted+
# Scores: [0.68391622 0.68598487]
#
# Mean: 0.6849505462537979
# Standard deviation: 0.0010343267179520055
#
# -----
# Dataset: smoted-
# Scores: [0.73007687 0.7303965 ]
#
# Mean: 0.7302366860998737
# Standard deviation: 0.00015981861416319854

# %% [markdown]
# #### 2.5 Árvores Extras

# %%
extrees = ExtraTreesClassifier(n_jobs=-1, random_state=1216)
for key in test_sets:
    X, y = df_splitter(datasets[key])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)
    extrees_test = cross_val_score(extrees,X_train,y_train, n_jobs=-1, cv=3, scoring='accuracy')
    first_results.append({'model':'Extra Trees', 'dataset':key, 'score':extrees_test.mean()})
    print(f'\n-----\nDataset: {key}')
    display_scores(extrees_test)
# Out:
# -----
# Dataset: numeric
# Scores: [0.74839708 0.74985259 0.75081073]
#
# Mean: 0.7496868023515727
# Standard deviation: 0.0009923175815198183
#
# -----
# Dataset: categoricals_binned
# Scores: [0.73793205 0.73776533 0.73540684]
#
# Mean: 0.7370347402699734
# Standard deviation: 0.0011531100974619445
#
# -----
# Dataset: one_hot_encoded
# Scores: [0.71648611 0.72435142 0.72199292]
#
# Mean: 0.7209434825543427
# Standard deviation: 0.0032956294397047925
#
# -----
# Dataset: outliers_removed
# Scores: [0.71857678 0.72222638 0.71848079]
#
# Mean: 0.7197613160341841
# Standard deviation: 0.0017435067655318006
#
# -----
# Dataset: one_hot_encoded_rescaled
# Scores: [0.71648611 0.72435142 0.72199292]
#
# Mean: 0.7209434825543427
# Standard deviation: 0.0032956294397047925
#
# -----
# Dataset: oversampled+
# Scores: [0.83142636 0.83515152 0.83369697]
#
# Mean: 0.8334249466447662
# Standard deviation: 0.0015329061255170064
#
# -----
# Dataset: oversampled-
# Scores: [0.83439271 0.82925988 0.83753819]
#
# Mean: 0.8337302586526795
# Standard deviation: 0.003411913276928968
#
# -----
# Dataset: smoted+
# Scores: [0.76078736 0.75830303 0.75646061]
#
# Mean: 0.7585169973760685
# Standard deviation: 0.0017728559222234788
#
# -----
# Dataset: smoted-
# Scores: [0.78980044 0.78303932 0.7873263 ]
#
# Mean: 0.7867220229223176
# Standard deviation: 0.002793093514993346

# %% [markdown]
# #### 2.6 Floresta aleatória

# %%
rnd_clf = RandomForestClassifier(n_estimators=70,
                                 max_leaf_nodes=None,
                                 bootstrap=True,
                                 oob_score=True,n_jobs = -1,
                                 random_state = 1216)
for key in test_sets:
    X, y = df_splitter(datasets[key])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)
    rnd_clf_test = cross_val_score(rnd_clf,X_train,y_train, n_jobs=-1, cv=3, scoring='accuracy')
    first_results.append({'model':'Random Forest', 'dataset':key, 'score':rnd_clf_test.mean()})
    print(f'\n-----\nDataset: {key}')
    display_scores(rnd_clf_test)
# Out:
# -----
# Dataset: numeric
# Scores: [0.75488245 0.75670696 0.7550855 ]
#
# Mean: 0.7555583018265367
# Standard deviation: 0.0008164410781646076
#
# -----
# Dataset: categoricals_binned
# Scores: [0.7478812  0.7499263  0.74985259]
#
# Mean: 0.7492200304343605
# Standard deviation: 0.0009471742677313469
#
# -----
# Dataset: one_hot_encoded
# Scores: [0.74471221 0.75051592 0.75014741]
#
# Mean: 0.7484585123768754
# Standard deviation: 0.002653303283560516
#
# -----
# Dataset: outliers_removed
# Scores: [0.74883895 0.75016855 0.75031838]
#
# Mean: 0.7497752930568754
# Standard deviation: 0.0006649128782569847
#
# -----
# Dataset: one_hot_encoded_rescaled
# Scores: [0.74478591 0.75051592 0.7500737 ]
#
# Mean: 0.7484585105663065
# Standard deviation: 0.002603189114267456
#
# -----
# Dataset: oversampled+
# Scores: [0.82846892 0.83612121 0.8326303 ]
#
# Mean: 0.8324068126234713
# Standard deviation: 0.003128028585296697
#
# -----
# Dataset: oversampled-
# Scores: [0.83178123 0.82743668 0.82970336]
#
# Mean: 0.8296404227649076
# Standard deviation: 0.0017742117696808272
#
# -----
# Dataset: smoted+
# Scores: [0.7717444  0.77144242 0.76901818]
#
# Mean: 0.7707350021107028
# Standard deviation: 0.0012202189197415957
#
# -----
# Dataset: smoted-
# Scores: [0.80881991 0.80314379 0.80467133]
#
# Mean: 0.8055450080498936
# Standard deviation: 0.0023982031894877556

# %% [markdown]
# #### 2.7 AdaBoost

# %%
ada_boost = AdaBoostClassifier(n_estimators = 500, learning_rate = 0.8, random_state = 1216)
for key in test_sets:
    X, y = df_splitter(datasets[key])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)
    ada_boost_test = cross_val_score(ada_boost,X_train,y_train, n_jobs=-1, cv=3, scoring='accuracy')
    first_results.append({'model':'AdaBoost', 'dataset':key, 'score':ada_boost_test.mean()})
    print(f'\n-----\nDataset: {key}')
    display_scores(ada_boost_test)
# Out:
# -----
# Dataset: numeric
# Scores: [0.75945169 0.75980248 0.75906545]
#
# Mean: 0.7594398719611991
# Standard deviation: 0.0003010065924008337
#
# -----
# Dataset: categoricals_binned
# Scores: [0.75996757 0.75980248 0.75994988]
#
# Mean: 0.7599066438784113
# Standard deviation: 7.401075954548328e-05
#
# -----
# Dataset: one_hot_encoded
# Scores: [0.75989388 0.75980248 0.75987618]
#
# Mean: 0.7598575104688545
# Standard deviation: 3.957989254669246e-05
#
# -----
# Dataset: outliers_removed
# Scores: [0.76022472 0.76028167 0.76020676]
#
# Mean: 0.760237715066819
# Standard deviation: 3.193349830681007e-05
#
# -----
# Dataset: one_hot_encoded_rescaled
# Scores: [0.75989388 0.75980248 0.75994988]
#
# Mean: 0.7598820780789174
# Standard deviation: 6.0753578180248605e-05
#
# -----
# Dataset: oversampled+
# Scores: [0.56530592 0.56213333 0.55873939]
#
# Mean: 0.5620595506113203
# Standard deviation: 0.0026812825313568974
#
# -----
# Dataset: oversampled-
# Scores: [0.56132052 0.55627279 0.55533655]
#
# Mean: 0.5576432883196627
# Standard deviation: 0.0026281390582369975
#
# -----
# Dataset: smoted+
# Scores: [0.75787841 0.75510303 0.75471515]
#
# Mean: 0.7558988625712179
# Standard deviation: 0.0014086769958534674
#
# -----
# Dataset: smoted-
# Scores: [0.81842818 0.81630038 0.81905982]
#
# Mean: 0.8179294630895129
# Standard deviation: 0.0011804418030813039

# %% [markdown]
# #### 2.8 Analisando os resultados

# %%
#Printing results comparison chart
results = first_results
results = pd.DataFrame(results)
results = results.pivot(index='model', columns = 'dataset', values = 'score')
results = results.reindex(columns= [ 'numeric','categoricals_binned','one_hot_encoded','one_hot_encoded_rescaled','outliers_removed','oversampled+','oversampled-','smoted+','smoted-'])
results = results.reindex(['KNN', 'Naive Bayes', 'Support Vector Machine', 'Decision Tree', 'Extra Trees', 'Random Forest', 'AdaBoost'])
results.style.background_gradient(cmap='bwr_r', low=0.7, high=0.8, axis=0)
# Out:
# <style type="text/css">
# #T_4e78a_row0_col0 {
#   background-color: #fff6f6;
#   color: #000000;
# }
# #T_4e78a_row0_col1 {
#   background-color: #f8f8ff;
#   color: #000000;
# }
# #T_4e78a_row0_col2 {
#   background-color: #fcfcff;
#   color: #000000;
# }
# #T_4e78a_row0_col3 {
#   background-color: #f2f2ff;
#   color: #000000;
# }
# #T_4e78a_row0_col4 {
#   background-color: #fafaff;
#   color: #000000;
# }
# #T_4e78a_row0_col5 {
#   background-color: #ffcece;
#   color: #000000;
# }
# #T_4e78a_row0_col6 {
#   background-color: #ffd0d0;
#   color: #000000;
# }
# #T_4e78a_row0_col7, #T_4e78a_row2_col5, #T_4e78a_row2_col6, #T_4e78a_row2_col8, #T_4e78a_row3_col0, #T_4e78a_row3_col1, #T_4e78a_row3_col2, #T_4e78a_row3_col3, #T_4e78a_row3_col4 {
#   background-color: #ff8e8e;
#   color: #000000;
# }
# #T_4e78a_row0_col8 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_4e78a_row1_col0, #T_4e78a_row4_col0 {
#   background-color: #babaff;
#   color: #000000;
# }
# #T_4e78a_row1_col1, #T_4e78a_row1_col4, #T_4e78a_row4_col7 {
#   background-color: #b4b4ff;
#   color: #000000;
# }
# #T_4e78a_row1_col2, #T_4e78a_row5_col1, #T_4e78a_row5_col4, #T_4e78a_row6_col7 {
#   background-color: #b6b6ff;
#   color: #000000;
# }
# #T_4e78a_row1_col3 {
#   background-color: #e0e0ff;
#   color: #000000;
# }
# #T_4e78a_row1_col5 {
#   background-color: #ff9292;
#   color: #000000;
# }
# #T_4e78a_row1_col6 {
#   background-color: #ffa0a0;
#   color: #000000;
# }
# #T_4e78a_row1_col7 {
#   background-color: #d2d2ff;
#   color: #000000;
# }
# #T_4e78a_row1_col8 {
#   background-color: #ffe4e4;
#   color: #000000;
# }
# #T_4e78a_row2_col0, #T_4e78a_row2_col1, #T_4e78a_row2_col2, #T_4e78a_row2_col3, #T_4e78a_row2_col4, #T_4e78a_row4_col5, #T_4e78a_row4_col6, #T_4e78a_row5_col7, #T_4e78a_row6_col8 {
#   background-color: #a2a2ff;
#   color: #f1f1f1;
# }
# #T_4e78a_row2_col7 {
#   background-color: #ffd8d8;
#   color: #000000;
# }
# #T_4e78a_row3_col5 {
#   background-color: #e6e6ff;
#   color: #000000;
# }
# #T_4e78a_row3_col6 {
#   background-color: #e2e2ff;
#   color: #000000;
# }
# #T_4e78a_row3_col7 {
#   background-color: #ffeaea;
#   color: #000000;
# }
# #T_4e78a_row3_col8 {
#   background-color: #dcdcff;
#   color: #000000;
# }
# #T_4e78a_row4_col1 {
#   background-color: #cacaff;
#   color: #000000;
# }
# #T_4e78a_row4_col2, #T_4e78a_row4_col3 {
#   background-color: #e8e8ff;
#   color: #000000;
# }
# #T_4e78a_row4_col4 {
#   background-color: #eaeaff;
#   color: #000000;
# }
# #T_4e78a_row4_col8, #T_4e78a_row5_col2, #T_4e78a_row5_col3 {
#   background-color: #b8b8ff;
#   color: #000000;
# }
# #T_4e78a_row5_col0 {
#   background-color: #aeaeff;
#   color: #000000;
# }
# #T_4e78a_row5_col5, #T_4e78a_row6_col0, #T_4e78a_row6_col1, #T_4e78a_row6_col2, #T_4e78a_row6_col3, #T_4e78a_row6_col4 {
#   background-color: #a4a4ff;
#   color: #000000;
# }
# #T_4e78a_row5_col6 {
#   background-color: #a6a6ff;
#   color: #000000;
# }
# #T_4e78a_row5_col8 {
#   background-color: #aaaaff;
#   color: #000000;
# }
# #T_4e78a_row6_col5 {
#   background-color: #ffa8a8;
#   color: #000000;
# }
# #T_4e78a_row6_col6 {
#   background-color: #ffaeae;
#   color: #000000;
# }
# </style>
# <table id="T_4e78a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th id="T_4e78a_level0_col0" class="col_heading level0 col0" >numeric</th>
#       <th id="T_4e78a_level0_col1" class="col_heading level0 col1" >categoricals_binned</th>
#       <th id="T_4e78a_level0_col2" class="col_heading level0 col2" >one_hot_encoded</th>
#       <th id="T_4e78a_level0_col3" class="col_heading level0 col3" >one_hot_encoded_rescaled</th>
#       <th id="T_4e78a_level0_col4" class="col_heading level0 col4" >outliers_removed</th>
#       <th id="T_4e78a_level0_col5" class="col_heading level0 col5" >oversampled+</th>
#       <th id="T_4e78a_level0_col6" class="col_heading level0 col6" >oversampled-</th>
#       <th id="T_4e78a_level0_col7" class="col_heading level0 col7" >smoted+</th>
#       <th id="T_4e78a_level0_col8" class="col_heading level0 col8" >smoted-</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e78a_level0_row0" class="row_heading level0 row0" >KNN</th>
#       <td id="T_4e78a_row0_col0" class="data row0 col0" >0.713107</td>
#       <td id="T_4e78a_row0_col1" class="data row0 col1" >0.709446</td>
#       <td id="T_4e78a_row0_col2" class="data row0 col2" >0.709421</td>
#       <td id="T_4e78a_row0_col3" class="data row0 col3" >0.714826</td>
#       <td id="T_4e78a_row0_col4" class="data row0 col4" >0.711671</td>
#       <td id="T_4e78a_row0_col5" class="data row0 col5" >0.620337</td>
#       <td id="T_4e78a_row0_col6" class="data row0 col6" >0.612765</td>
#       <td id="T_4e78a_row0_col7" class="data row0 col7" >0.616281</td>
#       <td id="T_4e78a_row0_col8" class="data row0 col8" >0.651036</td>
#     </tr>
#     <tr>
#       <th id="T_4e78a_level0_row1" class="row_heading level0 row1" >Naive Bayes</th>
#       <td id="T_4e78a_row1_col0" class="data row1 col0" >0.749122</td>
#       <td id="T_4e78a_row1_col1" class="data row1 col1" >0.749859</td>
#       <td id="T_4e78a_row1_col2" class="data row1 col2" >0.749367</td>
#       <td id="T_4e78a_row1_col3" class="data row1 col3" >0.725169</td>
#       <td id="T_4e78a_row1_col4" class="data row1 col4" >0.750774</td>
#       <td id="T_4e78a_row1_col5" class="data row1 col5" >0.529834</td>
#       <td id="T_4e78a_row1_col6" class="data row1 col6" >0.534287</td>
#       <td id="T_4e78a_row1_col7" class="data row1 col7" >0.735228</td>
#       <td id="T_4e78a_row1_col8" class="data row1 col8" >0.634644</td>
#     </tr>
#     <tr>
#       <th id="T_4e78a_level0_row2" class="row_heading level0 row2" >Support Vector Machine</th>
#       <td id="T_4e78a_row2_col0" class="data row2 col0" >0.760373</td>
#       <td id="T_4e78a_row2_col1" class="data row2 col1" >0.760373</td>
#       <td id="T_4e78a_row2_col2" class="data row2 col2" >0.760373</td>
#       <td id="T_4e78a_row2_col3" class="data row2 col3" >0.760373</td>
#       <td id="T_4e78a_row2_col4" class="data row2 col4" >0.760388</td>
#       <td id="T_4e78a_row2_col5" class="data row2 col5" >0.523806</td>
#       <td id="T_4e78a_row2_col6" class="data row2 col6" >0.506463</td>
#       <td id="T_4e78a_row2_col7" class="data row2 col7" >0.671197</td>
#       <td id="T_4e78a_row2_col8" class="data row2 col8" >0.505067</td>
#     </tr>
#     <tr>
#       <th id="T_4e78a_level0_row3" class="row_heading level0 row3" >Decision Tree</th>
#       <td id="T_4e78a_row3_col0" class="data row3 col0" >0.664095</td>
#       <td id="T_4e78a_row3_col1" class="data row3 col1" >0.638840</td>
#       <td id="T_4e78a_row3_col2" class="data row3 col2" >0.642304</td>
#       <td id="T_4e78a_row3_col3" class="data row3 col3" >0.642206</td>
#       <td id="T_4e78a_row3_col4" class="data row3 col4" >0.645001</td>
#       <td id="T_4e78a_row3_col5" class="data row3 col5" >0.730800</td>
#       <td id="T_4e78a_row3_col6" class="data row3 col6" >0.732454</td>
#       <td id="T_4e78a_row3_col7" class="data row3 col7" >0.684951</td>
#       <td id="T_4e78a_row3_col8" class="data row3 col8" >0.730237</td>
#     </tr>
#     <tr>
#       <th id="T_4e78a_level0_row4" class="row_heading level0 row4" >Extra Trees</th>
#       <td id="T_4e78a_row4_col0" class="data row4 col0" >0.749687</td>
#       <td id="T_4e78a_row4_col1" class="data row4 col1" >0.737035</td>
#       <td id="T_4e78a_row4_col2" class="data row4 col2" >0.720943</td>
#       <td id="T_4e78a_row4_col3" class="data row4 col3" >0.720943</td>
#       <td id="T_4e78a_row4_col4" class="data row4 col4" >0.719761</td>
#       <td id="T_4e78a_row4_col5" class="data row4 col5" >0.833425</td>
#       <td id="T_4e78a_row4_col6" class="data row4 col6" >0.833730</td>
#       <td id="T_4e78a_row4_col7" class="data row4 col7" >0.758517</td>
#       <td id="T_4e78a_row4_col8" class="data row4 col8" >0.786722</

# %% [markdown]
# O gráfico de resultado mostra que os melhores resultados foram com:
# * Árvores extras com o dataset 'oversampled-'
# * Floresta aleatória com o dataset 'oversampled+'
# * AdaBoost com o dataset 'smoted-'
#
# Algumas observações já podem ser feitas:
#
# * Máquina de Vetores de Suporte e AdaBoost tiveram bons resultados de plano com os datasets não reamostrados.
# * Árvore de Decisão teve resultados melhores com os datasets reamostrados.
# * Floresta aleatória teve melhores resultados com o dataset rebalanceado.
# * Os modelos foram significativamente piores usando o SMOTE Borderline e RobustScaler, do que simplesmente removendo os outliers.
# * AdaBoost se beneficiou bastante dos dados reamostrados usando o SMOTE.
# * Árvores extras e Floresta aleatória tiveram resultados próximos.

# %% [markdown]
# ### 3. Usando Grid Search com os modelos

# %% [markdown]
# #### 3.1 Árvores Extras

# %%
#Preparing the classifier
extra_tree = ExtraTreesClassifier(n_estimators=1000, random_state=1216, n_jobs = -1)
X, y = df_splitter(datasets['oversampled-'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)

# %%
#Setting the parameters for the grid search
min_samples_split = np.array([2,10,40])
max_depth = np.array([10,50,100,None])
max_leaf_nodes = np.array([5,20,None])
values_grid = {'min_samples_split': min_samples_split,
               'max_depth': max_depth,
               'max_leaf_nodes':max_leaf_nodes}

# %%
#Using grid search to find the best values
gridExtraTrees = GridSearchCV(estimator = extra_tree,
                                param_grid = values_grid,
                                cv = 2, verbose = 3,
                                scoring='accuracy',
                                pre_dispatch=-1)
gridExtraTrees.fit(X_train, y_train);
# Out:
# Fitting 2 folds for each of 36 candidates, totalling 72 fits
# [CV 1/2] END max_depth=10, max_leaf_nodes=5, min_samples_split=2;, score=0.568 total time=   3.3s
# [CV 2/2] END max_depth=10, max_leaf_nodes=5, min_samples_split=2;, score=0.559 total time=   3.3s
# [CV 1/2] END max_depth=10, max_leaf_nodes=5, min_samples_split=10;, score=0.568 total time=   3.6s
# [CV 2/2] END max_depth=10, max_leaf_nodes=5, min_samples_split=10;, score=0.559 total time=   3.2s
# [CV 1/2] END max_depth=10, max_leaf_nodes=5, min_samples_split=40;, score=0.568 total time=   3.3s
# [CV 2/2] END max_depth=10, max_leaf_nodes=5, min_samples_split=40;, score=0.559 total time=   3.2s
# [CV 1/2] END max_depth=10, max_leaf_nodes=20, min_samples_split=2;, score=0.579 total time=   4.5s
# [CV 2/2] END max_depth=10, max_leaf_nodes=20, min_samples_split=2;, score=0.573 total time=   4.3s
# [CV 1/2] END max_depth=10, max_leaf_nodes=20, min_samples_split=10;, score=0.579 total time=   4.5s
# [CV 2/2] END max_depth=10, max_leaf_nodes=20, min_samples_split=10;, score=0.574 total time=   4.1s
# [CV 1/2] END max_depth=10, max_leaf_nodes=20, min_samples_split=40;, score=0.580 total time=   5.0s
# [CV 2/2] END max_depth=10, max_leaf_nodes=20, min_samples_split=40;, score=0.572 total time=   4.7s
# [CV 1/2] END max_depth=10, max_leaf_nodes=None, min_samples_split=2;, score=0.619 total time=   9.9s
# [CV 2/2] END max_depth=10, max_leaf_nodes=None, min_samples_split=2;, score=0.609 total time=  10.1s
# [CV 1/2] END max_depth=10, max_leaf_nodes=None, min_samples_split=10;, score=0.610 total time=   8.2s
# [CV 2/2] END max_depth=10, max_leaf_nodes=None, min_samples_split=10;, score=0.601 total time=   7.7s
# [CV 1/2] END max_depth=10, max_leaf_nodes=None, min_samples_split=40;, score=0.600 total time=   8.5s
# [CV 2/2] END max_depth=10, max_leaf_nodes=None, min_samples_split=40;, score=0.593 total time=   7.9s
# [CV 1/2] END max_depth=50, max_leaf_nodes=5, min_samples_split=2;, score=0.568 total time=   3.3s
# [CV 2/2] END max_depth=50, max_leaf_nodes=5, min_samples_split=2;, score=0.559 total time=   3.3s
# [CV 1/2] END max_depth=50, max_leaf_nodes=5, min_samples_split=10;, score=0.568 total time=   3.4s
# [CV 2/2] END max_depth=50, max_leaf_nodes=5, min_samples_split=10;, score=0.559 total time=   3.3s
# [CV 1/2] END max_depth=50, max_leaf_nodes=5, min_samples_split=40;, score=0.568 total time=   3.4s
# [CV 2/2] END max_depth=50, max_leaf_nodes=5, min_samples_split=40;, score=0.559 total time=   3.2s
# [CV 1/2] END max_depth=50, max_leaf_nodes=20, min_samples_split=2;, score=0.580 total time=   4.2s
# [CV 2/2] END max_depth=50, max_leaf_nodes=20, min_samples_split=2;, score=0.573 total time=   4.0s
# [CV 1/2] END max_depth=50, max_leaf_nodes=20, min_samples_split=10;, score=0.580 total time=   4.1s
# [CV 2/2] END max_depth=50, max_leaf_nodes=20, min_samples_split=10;, score=0.573 total time=   3.8s
# [CV 1/2] END max_depth=50, max_leaf_nodes=20, min_samples_split=40;, score=0.580 total time=   4.1s
# [CV 2/2] END max_depth=50, max_leaf_nodes=20, min_samples_split=40;, score=0.573 total time=   3.7s
# [CV 1/2] END max_depth=50, max_leaf_nodes=None, min_samples_split=2;, score=0.779 total time=  23.4s
# [CV 2/2] END max_depth=50, max_leaf_nodes=None, min_samples_split=2;, score=0.778 total time=  24.4s
# [CV 1/2] END max_depth=50, max_leaf_nodes=None, min_samples_split=10;, score=0.734 total time=  18.2s
# [CV 2/2] END max_depth=50, max_leaf_nodes=None, min_samples_split=10;, score=0.739 total time=  19.0s
# [CV 1/2] END max_depth=50, max_leaf_nodes=None, min_samples_split=40;, score=0.672 total time=  13.2s
# [CV 2/2] END max_depth=50, max_leaf_nodes=None, min_samples_split=40;, score=0.675 total time=  13.5s
# [CV 1/2] END max_depth=100, max_leaf_nodes=5, min_samples_split=2;, score=0.568 total time=   3.4s
# [CV 2/2] END max_depth=100, max_leaf_nodes=5, min_samples_split=2;, score=0.559 total time=   3.5s
# [CV 1/2] END max_depth=100, max_leaf_nodes=5, min_samples_split=10;, score=0.568 total time=   3.6s
# [CV 2/2] END max_depth=100, max_leaf_nodes=5, min_samples_split=10;, score=0.559 total time=   4.4s
# [CV 1/2] END max_depth=100, max_leaf_nodes=5, min_samples_split=40;, score=0.568 total time=   3.3s
# [CV 2/2] END max_depth=100, max_leaf_nodes=5, min_samples_split=40;, score=0.559 total time=   3.1s
# [CV 1/2] END max_depth=100, max_leaf_nodes=20, min_samples_split=2;, score=0.580 total time=   4.3s
# [CV 2/2] END max_depth=100, max_leaf_nodes=20, min_samples_split=2;, score=0.573 total time=   3.8s
# [CV 1/2] END max_depth=100, max_leaf_nodes=20, min_samples_split=10;, score=0.580 total time=   4.3s
# [CV 2/2] END max_depth=100, max_leaf_nodes=20, min_samples_split=10;, score=0.573 total time=   4.1s
# [CV 1/2] END max_depth=100, max_leaf_nodes=20, min_samples_split=40;, score=0.580 total time=   4.4s
# [CV 2/2] END max_depth=100, max_leaf_nodes=20, min_samples_split=40;, score=0.573 total time=   4.0s
# [CV 1/2] END max_depth=100, max_leaf_nodes=None, min_samples_split=2;, score=0.779 total time=  24.4s
# [CV 2/2] END max_depth=100, max_leaf_nodes=None, min_samples_split=2;, score=0.778 total time=  23.6s
# [CV 1/2] END max_depth=100, max_leaf_nodes=None, min_samples_split=10;, score=0.734 total time=  16.1s
# [CV 2/2] END max_depth=100, max_leaf_nodes=None, min_samples_split=10;, score=0.739 total time=  16.3s
# [CV 1/2] END max_depth=100, max_leaf_nodes=None, min_samples_split=40;, score=0.672 total time=  13.7s
# [CV 2/2] END max_depth=100, max_leaf_nodes=None, min_samples_split=40;, score=0.675 total time=  13.4s
# [CV 1/2] END max_depth=None, max_leaf_nodes=5, min_samples_split=2;, score=0.568 total time=   3.8s
# [CV 2/2] END max_depth=None, max_leaf_nodes=5, min_samples_split=2;, score=0.559 total time=   3.2s
# [CV 1/2] END max_depth=None, max_leaf_nodes=5, min_samples_split=10;, score=0.568 total time=   3.5s
# [CV 2/2] END max_depth=None, max_leaf_nodes=5, min_samples_split=10;, score=0.559 total time=   3.6s
# [CV 1/2] END max_depth=None, max_leaf_nodes=5, min_samples_split=40;, score=0.568 total time=   3.8s
# [CV 2/2] END max_depth=None, max_leaf_nodes=5, min_samples_split=40;, score=0.559 total time=   3.7s
# [CV 1/2] END max_depth=None, max_leaf_nodes=20, min_samples_split=2;, score=0.580 total time=   4.2s
# [CV 2/2] END max_depth=None, max_leaf_nodes=20, min_samples_split=2;, score=0.573 total time=   4.0s
# [CV 1/2] END max_depth=None, max_leaf_nodes=20, min_samples_split=10;, score=0.580 total time=   6.0s
# [CV 2/2] END max_depth=None, max_leaf_nodes=20, min_samples_split=10;, score=0.573 total time=   5.3s
# [CV 1/2] END max_depth=None, max_leaf_nodes=20, min_samples_split=40;, score=0.580 total time=   5.1s
# [CV 2/2] END max_depth=None, max_leaf_nodes=20, min_samples_split=40;, score=0.573 total time=   3.8s
# [CV 1/2] END max_depth=None, max_leaf_nodes=None, min_samples_split=2;, score=0.779 total time=  26.7s
# [CV 2/2] END max_depth=None, max_leaf_nodes=None, min_samples_split=2;, score=0.778 total time=  24.2s
# [CV 1/2] END max_depth=None, max_leaf_nodes=None, min_samples_split=10;, score=0.734 total time=  19.6s
# [CV 2/2] END max_depth=None, max_leaf_nodes=None, min_samples_split=10;, score=0.739 total time=  18.4s
# [CV 1/2] END max_depth=None, max_leaf_nodes=None, min_samples_split=40;, score=0.672 total time=  14.2s
# [CV 2/2] END max_depth=None, max_leaf_nodes=None, min_samples_split=40;, score=0.675 total time=  14.8s

# %%
extra_trees_results = pd.DataFrame(gridExtraTrees.cv_results_)
extra_trees_results.sort_values(by=['mean_test_score'], ascending=False)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 15      20.788077      0.430913         3.250595        0.068455
# 24      20.995173      0.496355         3.149751        0.092315
# 33      22.326006      1.296914         3.258998        0.057538
# 16      16.083295      0.514300         2.607123        0.129331
# 34      16.322945      0.358101         2.788210        0.237688
# 25      13.942547      0.042464         2.364602        0.057508
# 26      11.565588      0.103171         2.075559        0.062541
# 17      10.900350      0.095924         2.591187        0.239595
# 35      12.410065      0.086075         2.213723        0.214518
# 6        8.538758      0.119055         1.550643        0.008435
# 7        6.687209      0.100030         1.391579        0.163597
# 8        6.889730      0.333417         1.404478        0.046972
# 31       4.963500      0.303231         0.800286        0.040094
# 13       3.419897      0.150965         0.656829        0.004849
# 22       3.556234      0.096031         0.747723        0.007876
# 4        3.597399      0.124142         0.772466        0.065730
# 30       3.495244      0.163577         0.738112        0.064113
# 21       3.430851      0.173571         0.710342        0.059207
# 12       3.526955      0.075880         0.669971        0.017136
# 3        3.788129      0.005490         0.712918        0.060209
# 32       3.793103      0.607056         0.714271        0.049465
# 14       3.339249      0.164391         0.682617        0.046654
# 23       3.543632      0.138748         0.786020        0.058702
# 5        4.085775      0.281551         0.860356        0.168818
# 27       2.922694      0.295387         0.663309        0.004329
# 0        2.826495      0.029438         0.593377        0.010452
# 9        2.739818      0.049579         0.661075        0.067840
# 18       2.780998      0.147400         0.770788        0.139895
# 20       2.702475      0.079719         0.634702        0.022562
# 29       3.171248      0.000615         0.677884        0.028797
# 11       2.752212      0.015238         0.620329        0.069364
# 2        2.740123      0.021795         0.619230        0.055486
# 19       3.328017      0.461692         0.775465        0.088859
# 28       2.924683      0.144321         0.742128        0.110502
# 1        2.871942      0.232608         0.587520        0.031333
# 10       2.788637      0.072910         0.653942        0.043008
#
#    param_max_depth param_max_leaf_nodes param_min_samples_split  \
# 15              50                 None                       2
# 24             100                 None                       2
# 33            None                 None                       2
# 16              50                 None                      10
# 34            None                 None                      10
# 25             100                 None                      10
# 26             100                 None                      40
# 17              50                 None                      40
# 35            None                 None                      40
# 6               10                 None                       2
# 7               10                 None                      10
# 8               10                 None                      40
# 31            None                   20                      10
# 13              50                   20                      10
# 22             100                   20                      10
# 4               10                   20                      10
# 30            None                   20                       2
# 21             100                   20                       2
# 12              50                   20                       2
# 3               10                   20                       2
# 32            None                   20                      40
# 14              50                   20                      40
# 23             100                   20                      40
# 5               10                   20                      40
# 27            None                    5                       2
# 0               10                    5                       2
# 9               50                    5                       2
# 18             100                    5                       2
# 20             100                    5                      40
# 29            None                    5                      40
# 11              50                    5                      40
# 2               10                    5                      40
# 19             100                    5                      10
# 28            None                    5                      10
# 1               10                    5                      10
# 10              50                    5                      10
#
#                                                params  split0_test_score  \
# 15  {'max_depth': 50, 'max_leaf_nodes': None, 'min...           0.778990
# 24  {'max_depth': 100, 'max_leaf_nodes': None, 'mi...           0.778563
# 33  {'max_depth': None, 'max_leaf_nodes': None, 'm...           0.778563
# 16  {'max_depth': 50, 'max_leaf_nodes': None, 'min...           0.734380
# 34  {'max_depth': None, 'max_leaf_nodes': None, 'm...           0.734183
# 25  {'max_depth': 100, 'max_leaf_nodes': None, 'mi...           0.734183
# 26  {'max_depth': 100, 'max_leaf_nodes': None, 'mi...           0.671934
# 17  {'max_depth': 50, 'max_leaf_nodes': None, 'min...           0.671934
# 35  {'max_depth': None, 'max_leaf_nodes': None, 'm...           0.671934
# 6   {'max_depth': 10, 'max_leaf_nodes': None, 'min...           0.618586
# 7   {'max_depth': 10, 'max_leaf_nodes': None, 'min...           0.610177
# 8   {'max_depth': 10, 'max_leaf_nodes': None, 'min...           0.600158
# 31  {'max_depth': None, 'max_leaf_nodes': 20, 'min...           0.579988
# 13  {'max_depth': 50, 'max_leaf_nodes': 20, 'min_s...           0.579988
# 22  {'max_depth': 100, 'max_leaf_nodes': 20, 'min_...           0.579988
# 4   {'max_depth': 10, 'max_leaf_nodes': 20, 'min_s...           0.579134
# 30  {'max_depth': None, 'max_leaf_nodes': 20, 'min...           0.579890
# 21  {'max_depth': 100, 'max_leaf_nodes': 20, 'min_...           0.579890
# 12  {'max_depth': 50, 'max_leaf_nodes': 20, 'min_s...           0.579890
# 3   {'max_depth': 10, 'max_leaf_nodes': 20, 'min_s...           0.579463
# 32  {'max_depth': None, 'max_leaf_nodes': 20, 'min...           0.579528
# 14  {'max_depth': 50, 'max_leaf_nodes': 20, 'min_s...           0.579528
# 23  {'max_depth': 100, 'max_leaf_nodes': 20, 'min_...           0.579528
# 5   {'max_depth': 10, 'max_leaf_nodes': 20, 'min_s...           0.579725
# 27  {'max_depth': None, 'max_leaf_nodes': 5, 'min_...           0.568261
# 0   {'max_depth': 10, 'max_leaf_nodes': 5, 'min_sa...           0.568261
# 9   {'max_depth': 50, 'max_leaf_nodes': 5, 'min_sa...           0.568261
# 18  {'max_depth': 100, 'max_leaf_nodes': 5, 'min_s...           0.568261
# 20  {'max_depth': 100, 'max_leaf_nodes': 5, 'min_s...           0.568130
# 29  {'max_depth': None, 'max_leaf_nodes': 5, 'min_...           0.568130
# 11  {'max_depth': 50, 'max_leaf_nodes': 5, 'min_sa...           0.568130
# 2   {'max_depth': 10, 'max_leaf_nodes': 5, 'min_sa...           0.568130
# 19  {'max_depth': 100, 'max_leaf_nodes': 5, 'min_s...           0.568261
# 28  {'max_depth': None, 'max_leaf_nodes': 5, 'min_...           0.568261
# 1   {'max_depth': 10, 'max_leaf_nodes': 5, 'min_sa...           0.568261
# 10  {'max_depth': 50, 'max_leaf_nodes': 5, 'min_sa...           0.568261
#
#     split1_test_score  mean_test_score  std_test_score  rank_test_score
# 15           0.777570         0.778280        0.000710                1
# 24           0.777898         0.778230        0.000332                2
# 33           0.777898         0.778230        0.000332                2
# 16           0.739003         0.736692        0.002312                4
# 34           0.739003         0.736593        0.002410                5
# 25           0.739003         0.736593        0.002410                5
# 26           0.674978         0.673456        0.001522                7
# 17           0.674978         0.673456        0.001522                7
# 35           0.674978         0.673456        0.001522                7
# 6            0.609178         0.613882        0.004704               10
# 7            0.600900         0.605538        0.004638               11
# 8            0.593049         0.596603        0.003554               12
# 31           0.572977         0.576483        0.003505               13
# 13           0.572977         0.576483        0.003505               13
# 22           0.572977         0.576483        0.003505               13
# 4            0.573798         0.576466        0.002668               16
# 30           0.573010         0.576450        0.003440               17
# 21           0.573010         0.576450        0.003440               17
# 12           0.573010         0.576450        0.003440               17
# 3            0.573404         0.576433        0.003029               20
# 32           0.572846         0.576187        0.003341               21
# 14           0.572846         0.576187        0.003341               21
# 23           0.572846         0.576187        0.003341               21
# 5            0.572222         0.575974        0.003752               24
# 27           0.559049         0.563655        0.004606               25
# 0            0.559049         0.563655        0.004606               25
# 9            0.559049         0.563655        0.004606               25
# 18           0.559049         0.563655        0.004606               25
# 20           0.559016         0.563573        0.004557               29
# 29           0.559016         0.563573        0.004557               29
# 11           0.559016         0.563573        0.004557               29
# 2            0.559016         0.563573        0.004557               29
# 19           0.558884         0.563573        0.004688               33
# 28           0.558884         0.563573        0.004688               33
# 1            0.558884         0.563573        0.004688               33
# 10           0.558884         0.563573        0.004688               33

# %%
print(gridExtraTrees.best_estimator_)
# Out:
# ExtraTreesClassifier(max_depth=50, n_estimators=1000, n_jobs=-1,
#                      random_state=1216)

# %%
best_extra_trees = gridExtraTrees.best_estimator_
best_extra_trees.fit(X_train, y_train);

# %%
teste_xtr = best_extra_trees.predict(X_test)
print(classification_report(y_test, teste_xtr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      7581
#            1       0.88      0.93      0.91      7640
#
#     accuracy                           0.90     15221
#    macro avg       0.91      0.90      0.90     15221
# weighted avg       0.91      0.90      0.90     15221

# %% [markdown]
# Após fazer grid search com alguns parâmetros, o modelo de árvores extras teve um resultado significativo com o seu melhor resultado.

# %% [markdown]
# #### 3.2 Floresta aleatória

# %%
#Setting the Classifier
rand_forest = RandomForestClassifier(criterion='gini',
                                 max_leaf_nodes=None,
                                 bootstrap=True,
                                 oob_score=True,
                                 n_jobs = -1)
X, y = df_splitter(datasets['oversampled+'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)

# %%
# Grid search parameters
n_estimators = np.array([1000,2000])
max_depth = np.array([50,None])
values_grid_forest = {'n_estimators': n_estimators, 'max_depth': max_depth}

# %%
#Using grid search to find the best values
gridForest = GridSearchCV(estimator = rand_forest,
                                param_grid = values_grid_forest,
                                cv = 2, verbose = 3,
                                scoring='accuracy',
                                pre_dispatch=-1)
gridForest.fit(X_train, y_train);
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# [CV 1/2] END ...max_depth=50, n_estimators=1000;, score=0.779 total time=  31.4s
# [CV 2/2] END ...max_depth=50, n_estimators=1000;, score=0.782 total time=  29.6s
# [CV 1/2] END ...max_depth=50, n_estimators=2000;, score=0.779 total time=  57.2s
# [CV 2/2] END ...max_depth=50, n_estimators=2000;, score=0.781 total time=  58.8s
# [CV 1/2] END .max_depth=None, n_estimators=1000;, score=0.778 total time=  26.5s
# [CV 2/2] END .max_depth=None, n_estimators=1000;, score=0.780 total time=  26.2s
# [CV 1/2] END .max_depth=None, n_estimators=2000;, score=0.779 total time=  53.3s
# [CV 2/2] END .max_depth=None, n_estimators=2000;, score=0.781 total time=  55.9s

# %%
forest_results = pd.DataFrame(gridForest.cv_results_)
forest_results.sort_values(by=['mean_test_score'], ascending=False)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      27.848772      0.746842         2.742522        0.158408
# 1      52.158626      0.812655         5.959959        0.023476
# 3      49.265794      1.019699         5.435865        0.241771
# 2      23.760490      0.017741         2.681777        0.173825
#
#   param_max_depth param_n_estimators  \
# 0              50               1000
# 1              50               2000
# 3            None               2000
# 2            None               1000
#
#                                       params  split0_test_score  \
# 0    {'max_depth': 50, 'n_estimators': 1000}           0.778880
# 1    {'max_depth': 50, 'n_estimators': 2000}           0.779010
# 3  {'max_depth': None, 'n_estimators': 2000}           0.778848
# 2  {'max_depth': None, 'n_estimators': 1000}           0.777878
#
#    split1_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.781563         0.780222        0.001341                1
# 1           0.781208         0.780109        0.001099                2
# 3           0.781240         0.780044        0.001196                3
# 2           0.780496         0.779187        0.001309                4

# %%
print(gridForest.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=50, n_estimators=1000, n_jobs=-1,
#                        oob_score=True)

# %%
best_forest = gridForest.best_estimator_
best_forest.fit(X_train, y_train);

# %%
teste_rnd = best_forest.predict(X_test)
print(classification_report(y_test, teste_rnd))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90      7680
#            1       0.89      0.93      0.91      7790
#
#     accuracy                           0.91     15470
#    macro avg       0.91      0.90      0.91     15470
# weighted avg       0.91      0.91      0.91     15470

# %% [markdown]
# Após fazer grid search com alguns parâmetros, o floresta aleatória foi ligeiramente melhor.

# %% [markdown]
# #### 3.3 AdaBoost

# %%
#Setting the classifier
ada_boost = AdaBoostClassifier(random_state = 1216)
X, y = df_splitter(datasets['smoted-'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)

# %%
n_estimators = np.array([200,300,600])
learning_rate = np.array([1.0,1.5])
values_grid_ada = {'n_estimators': n_estimators, 'learning_rate': learning_rate}

# %%
#Using grid search to find the best values
gridAda = GridSearchCV(estimator = ada_boost,
                                param_grid = values_grid_ada,
                                cv = 2, verbose = 3,
                                scoring='accuracy',
                                pre_dispatch=-1)
gridAda.fit(X_train, y_train);
# Out:
# Fitting 2 folds for each of 6 candidates, totalling 12 fits
# [CV 1/2] END learning_rate=1.0, n_estimators=200;, score=0.814 total time=   7.6s
# [CV 2/2] END learning_rate=1.0, n_estimators=200;, score=0.815 total time=   7.6s
# [CV 1/2] END learning_rate=1.0, n_estimators=300;, score=0.817 total time=  11.0s
# [CV 2/2] END learning_rate=1.0, n_estimators=300;, score=0.817 total time=  11.3s
# [CV 1/2] END learning_rate=1.0, n_estimators=600;, score=0.817 total time=  20.9s
# [CV 2/2] END learning_rate=1.0, n_estimators=600;, score=0.818 total time=  23.0s
# [CV 1/2] END learning_rate=1.5, n_estimators=200;, score=0.817 total time=   7.6s
# [CV 2/2] END learning_rate=1.5, n_estimators=200;, score=0.818 total time=   8.4s
# [CV 1/2] END learning_rate=1.5, n_estimators=300;, score=0.817 total time=  11.1s
# [CV 2/2] END learning_rate=1.5, n_estimators=300;, score=0.817 total time=  10.9s
# [CV 1/2] END learning_rate=1.5, n_estimators=600;, score=0.817 total time=  21.5s
# [CV 2/2] END learning_rate=1.5, n_estimators=600;, score=0.817 total time=  23.1s

# %%
ada_results = pd.DataFrame(gridForest.cv_results_)
ada_results.sort_values(by=['mean_test_score'], ascending=False)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      27.848772      0.746842         2.742522        0.158408
# 1      52.158626      0.812655         5.959959        0.023476
# 3      49.265794      1.019699         5.435865        0.241771
# 2      23.760490      0.017741         2.681777        0.173825
#
#   param_max_depth param_n_estimators  \
# 0              50               1000
# 1              50               2000
# 3            None               2000
# 2            None               1000
#
#                                       params  split0_test_score  \
# 0    {'max_depth': 50, 'n_estimators': 1000}           0.778880
# 1    {'max_depth': 50, 'n_estimators': 2000}           0.779010
# 3  {'max_depth': None, 'n_estimators': 2000}           0.778848
# 2  {'max_depth': None, 'n_estimators': 1000}           0.777878
#
#    split1_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.781563         0.780222        0.001341                1
# 1           0.781208         0.780109        0.001099                2
# 3           0.781240         0.780044        0.001196                3
# 2           0.780496         0.779187        0.001309                4

# %%
print(gridAda.best_estimator_)
# Out:
# AdaBoostClassifier(n_estimators=600, random_state=1216)

# %%
best_ada = gridAda.best_estimator_
best_ada.fit(X_train, y_train);

# %%
teste_ada = best_ada.predict(X_test)
print(classification_report(y_test, teste_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.95      0.84      7581
#            1       0.93      0.68      0.79      7640
#
#     accuracy                           0.82     15221
#    macro avg       0.84      0.82      0.81     15221
# weighted avg       0.84      0.82      0.81     15221

# %% [markdown]
# Já o AdaBoost não melhorou usando grid search.

# %% [markdown]
# ### 4. Validação cruzada

# %% [markdown]
# #### 4.1 Árvores aleatórias

# %%
#Extra trees cross-validation
X, y = df_splitter(datasets['oversampled-'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)   #No fixed seed for a new train/test split
extrees = ExtraTreesClassifier(max_depth=50,
                               n_estimators=1000,
                               n_jobs=-1)  #No fixed seed this time, so the model can train new random states
extrees_test = cross_val_score(extrees,X_train,y_train, n_jobs=-1, cv=3, scoring='accuracy') #Only 3 to avoid excessive memory overload of our instance
display_scores(extrees_test)
# Out:
# Scores: [0.83104213 0.83541934 0.8330541 ]
#
# Mean: 0.8331718563429487
# Standard deviation: 0.0017889260701693106

# %% [markdown]
# A validação cruzada não demosntrou melhora significativa na validação cruzada.

# %%
X, y = df_splitter(datasets['oversampled-'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)
teste_xtr = best_extra_trees.predict(X_test)
print(classification_report(y_test, teste_xtr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      7581
#            1       0.88      0.93      0.91      7640
#
#     accuracy                           0.90     15221
#    macro avg       0.91      0.90      0.90     15221
# weighted avg       0.91      0.90      0.90     15221

# %%
#Getting ROC Graph
X, y = df_splitter(datasets['oversampled-'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)
y_pred = best_extra_trees.predict(X_test)
fpr, tpr, thresh = roc_curve(y_test, y_pred, pos_label=1)
plt.plot(fpr, tpr, label='Extra Trees ROC')
plt.title('Extra Trees ROC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate');

# %%
cm = ConfusionMatrix(best_extra_trees)
cm.fit(X_train, y_train)
cm.score(X_test, y_test)
# Out:
# 0.9038827935089678

# %%
feature_imp = pd.DataFrame(best_extra_trees.feature_importances_, index = X.columns)
plt.figure(figsize = (4,10))
sns.heatmap(feature_imp, annot=False, cmap='gist_earth_r').set(title='Extra Trees Feature Importance Map');

# %% [markdown]
# A árvore de importância do árvores extras em seu melhor resultado demonstra que as características mais imporantes foram : O prêmio do seguro, a idade do cliente, e há quanto tempo o cliente já faz parte da operadora ('Holding_Policy_Duration')

# %% [markdown]
# #### 4.2 Random forest

# %%
# Random forest cross-validation
X, y = df_splitter(datasets['oversampled+'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) #No fixed seed for a new train/test split
rand_forest = RandomForestClassifier(criterion='gini',
                                     max_leaf_nodes=None,
                                     bootstrap=True,
                                     oob_score=True,
                                     n_estimators=1000,
                                     n_jobs = -1) #No fixed seed this time, so the model can train new random states
rand_forest_test = cross_val_score(rand_forest,X_train,y_train, n_jobs=-1, cv=3, scoring='accuracy') #Only 3 to avoid excessive memory overload of our instance
display_scores(rand_forest_test)
# Out:
# Scores: [0.82701445 0.83461818 0.82938182]
#
# Mean: 0.83033814926145
# Standard deviation: 0.0031770132372734242

# %%
X, y = df_splitter(datasets['oversampled+'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)
teste_rnd = best_forest.predict(X_test)
print(classification_report(y_test, teste_rnd))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90      7680
#            1       0.89      0.93      0.91      7790
#
#     accuracy                           0.91     15470
#    macro avg       0.91      0.90      0.91     15470
# weighted avg       0.91      0.91      0.91     15470

# %%
#Getting ROC Graph
X, y = df_splitter(datasets['oversampled+'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1216)
y_pred = best_forest.predict(X_test)
fpr, tpr, thresh = roc_curve(y_test, y_pred, pos_label=1)
plt.plot(fpr, tpr, label='Random Forest ROC')
plt.title('Extra Trees ROC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate');

# %%
cm = ConfusionMatrix(best_forest)
cm.fit(X_train, y_train)
cm.score(X_test, y_test)
# Out:
# 0.9051712992889464

# %%
feature_imp = pd.DataFrame(best_forest.feature_importances_, index = X.columns)
plt.figure(figsize = (4,10))
sns.heatmap(feature_imp, annot=False, cmap='gist_earth_r').set(title='Random Forest Feature Importance Map');

# %% [markdown]
# Já o o modelo de floresta aleatória deu muito mais importância para o preço do seguro (observar a escala).

# %% [markdown]
# #### 4.3 Comparação dos melhores modelos com os outros datasets

# %%
last_results = []

# %%
for key in test_sets:
    X, y = df_splitter(datasets[key])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
    best_extra_trees_test = cross_val_score(best_extra_trees,X_train,y_train, n_jobs=-1, cv=3, scoring='accuracy')
    last_results.append({'model':'Extra Trees', 'dataset':key, 'score':best_extra_trees_test.mean()})
    print(f'\n-----\nDataset: {key}')
    display_scores(best_extra_trees_test)
# Out:
# -----
# Dataset: numeric
# Scores: [0.75191615 0.7504586  0.75052411]
#
# Mean: 0.7509662841512044
# Standard deviation: 0.0006721875135531555
#
# -----
# Dataset: categoricals_binned
# Scores: [0.73698002 0.74076258 0.73820755]
#
# Mean: 0.7386500484796548
# Standard deviation: 0.0015756043570846108
#
# -----
# Dataset: one_hot_encoded
# Scores: [0.72178185 0.71698113 0.72248428]
#
# Mean: 0.7204157542397381
# Standard deviation: 0.0024455158298871678
#
# -----
# Dataset: outliers_removed
# Scores: [0.72146757 0.71693967 0.72120123]
#
# Mean: 0.7198694899453989
# Standard deviation: 0.0020745454690900378
#
# -----
# Dataset: one_hot_encoded_rescaled
# Scores: [0.72217491 0.71553983 0.71750524]
#
# Mean: 0.7184066610999755
# Standard deviation: 0.0027827423340175635
#
# -----
# Dataset: oversampled+
# Scores: [0.85480952 0.85299948 0.85626859]
#
# Mean: 0.8546925281357519
# Standard deviation: 0.0013371669897449497
#
# -----
# Dataset: oversampled-
# Scores: [0.85256888 0.85375148 0.85213087]
#
# Mean: 0.8528170761975676
# Standard deviation: 0.0006844908629921752
#
# -----
# Dataset: smoted+
# Scores: [0.75844682 0.75943803 0.75899668]
#
# Mean: 0.7589605096345667
# Standard deviation: 0.0004054666694782199
#
# -----
# Dataset: smoted-
# Scores: [0.78612413 0.78717533 0.78353992]
#
# Mean: 0.7856131283488823
# Standard deviation: 0.0015275011051816324

# %%
for key in test_sets:
    X, y = df_splitter(datasets[key])
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
    best_forest_test = cross_val_score(best_forest,X_train,y_train, n_jobs=-1, cv=3, scoring='accuracy')
    last_results.append({'model':'Random Forest', 'dataset':key, 'score':best_forest_test.mean()})
    print(f'\n-----\nDataset: {key}')
    display_scores(best_forest_test)
# Out:
# -----
# Dataset: numeric
# Scores: [0.75728791 0.75478249 0.75727201]
#
# Mean: 0.7564474736217347
# Standard deviation: 0.0011773357409238564
#
# -----
# Dataset: categoricals_binned
# Scores: [0.75204717 0.75019654 0.75229298]
#
# Mean: 0.7515122281803214
# Standard deviation: 0.0009357280477393017
#
# -----
# Dataset: one_hot_encoded
# Scores: [0.74923027 0.7490173  0.75203092]
#
# Mean: 0.7500928277807191
# Standard deviation: 0.0013731951020676686
#
# -----
# Dataset: outliers_removed
# Scores: [0.7504994  0.74910108 0.75016647]
#
# Mean: 0.7499223154436897
# Standard deviation: 0.0005963967169416446
#
# -----
# Dataset: one_hot_encoded_rescaled
# Scores: [0.75132656 0.75019654 0.75176887]
#
# Mean: 0.7510973242801354
# Standard deviation: 0.0006620504675526223
#
# -----
# Dataset: oversampled+
# Scores: [0.85476642 0.85299948 0.85708745]
#
# Mean: 0.8549511160065159
# Standard deviation: 0.0016740060573256553
#
# -----
# Dataset: oversampled-
# Scores: [0.85659848 0.85291928 0.85318208]
#
# Mean: 0.8542332793132145
# Standard deviation: 0.0016758903657053314
#
# -----
# Dataset: smoted+
# Scores: [0.77301327 0.77624547 0.78183856]
#
# Mean: 0.7770324346169534
# Standard deviation: 0.0036456255818849794
#
# -----
# Dataset: smoted-
# Scores: [0.80618457 0.80837458 0.80745478]
#
# Mean: 0.8073379761435476
# Standard deviation: 0.0008978723000319684

# %%
#Printing results comparison chart
results = last_results
results = pd.DataFrame(results)
results = results.pivot(index='model', columns = 'dataset', values = 'score')
results = results.reindex(columns= [ 'numeric','categoricals_binned','one_hot_encoded','one_hot_encoded_rescaled','outliers_removed','oversampled+','oversampled-','smoted+','smoted-'])
results = results.reindex(['Random Forest','Extra Trees'])
results
# Out:
# dataset         numeric  categoricals_binned  one_hot_encoded  \
# model
# Random Forest  0.756447             0.751512         0.750093
# Extra Trees    0.750966             0.738650         0.720416
#
# dataset        one_hot_encoded_rescaled  outliers_removed  oversampled+  \
# model
# Random Forest                  0.751097          0.749922      0.854951
# Extra Trees                    0.718407          0.719869      0.854693
#
# dataset        oversampled-   smoted+   smoted-
# model
# Random Forest      0.854233  0.777032  0.807338
# Extra Trees        0.852817  0.758961  0.785613

# %%
plt.figure(figsize = (13,2))
sns.heatmap(results, annot=True, fmt='.4g',cmap='coolwarm_r', vmin=0.717, vmax=0.834).set(title='Best models dataset comparison');

# %%
print(results.mean(axis=1))
# Out:
# model
# Random Forest    0.783625
# Extra Trees      0.766710
# dtype: float64

# %% [markdown]
# Após comparar os modelos com os outros datasets, mas dessa vez sem usar o mesmo seed state para a divisão dos conjuntos, observa-se que os modelos se mantiveram relativamente acurados para os para os datasets rebalanceados com o random oversampler, sem significativa diferença com o robust scaler.
#
# Já os dados rebalanceados usando o SMOTE Borderline não tiveram resultados próximos, embora o Floresta aleatória conseguiu se manter próximo.
#
# Os valores de acurácia excelentes de 0.90 e 0.91 indicam a ser provável o overfitting.
#
# Porém, os resultados do último teste demonstram que esse é um valor mais próximo do que seria esperado em um modelo em produção.
#
# A título de comparação, seguem alguns resultados de competidores do Kaggle:
#
# | Modelo | Valores |
# | --- | --- |
# | Random Forest | 0.81, 0.90 |
# | Extra Trees | 0.85 |
# | XGB | 0.82 |
# | AdaBoost | 0,59 |
# | PyTorch | 0,75 |
